# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Rupikaupa2006/Flyrank-ML-internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# ### Finding 1
# The paper reports that content with growing impressions tends to be longer, younger, and slightly better positioned in search results than declining content.
#
# **Methodology question:**
# How were the "growing" and "declining" labels defined? Were they based on a fixed percentage change over a specific time window, and would the same conclusion hold if a different time window or threshold were used?
#
# ---
#
# ### Finding 2
# The paper reports that content performance tends to peak around 61–90 days after publication and generally declines after 270 days.
#
# **Methodology question:**
# Was this observation consistent across different clients and industries, or was it influenced by a small number of large websites? A grouped validation by client would help determine whether the pattern generalizes.
#
# These questions are intended to improve confidence in the methodology rather than challenge the findings. They focus on validation design and reproducibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %% [markdown]
# In Week 5, I evaluated my Random Forest model using a standard train-test split. For this validation, I use a grouped split based on the client so that content from the same client does not appear in both the training and testing sets.
#
# This validation design is more realistic because it measures how well the model generalizes to unseen clients rather than memorizing patterns from the same client.
#
# The grouped validation produced slightly lower performance than the random split, which is expected and provides a more honest estimate of model performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

comparison = pd.DataFrame({
    "Validation Method": [
        "Random Train/Test Split (Week 5)",
        "Grouped Validation by Client"
    ],
    "Accuracy": [
        0.7315,
        0.69
    ]
})

comparison
# Out:
#                   Validation Method  Accuracy
# 0  Random Train/Test Split (Week 5)    0.7315
# 1      Grouped Validation by Client    0.6900

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# I reviewed the features used in my Week 5 model to check for data leakage.
#
# The model uses search volume, word count, competition, clicks, and average search position as input features. These features are available before making the prediction and do not directly contain future outcome information.
#
# I did not use future impressions, manually assigned product flags, or any label-derived features when training the model. Therefore, the model is intended to support decision-making using information that would realistically be available at prediction time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
leakage_check = pd.DataFrame({
    "Feature": [
        "search_volume",
        "word_count",
        "competition",
        "gsc_clicks",
        "gsc_avg_position"
    ],
    "Available Before Prediction": [
        "Yes",
        "Yes",
        "Yes",
        "Yes",
        "Yes"
    ],
    "Leakage Risk": [
        "No",
        "No",
        "No",
        "No",
        "No"
    ]
})

leakage_check
# Out:
#             Feature Available Before Prediction Leakage Risk
# 0     search_volume                         Yes           No
# 1        word_count                         Yes           No
# 2       competition                         Yes           No
# 3        gsc_clicks                         Yes           No
# 4  gsc_avg_position                         Yes           No

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# ### Original Claim
#
# The Random Forest model accurately predicts content performance.
#
# ### Revised Claim
#
# In this dataset, the Random Forest model showed higher accuracy than the rule-based baseline. The observed results suggest that combining multiple content and search features can improve prediction performance. These results should be used as decision support and may not generalize to every client or future dataset without additional validation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Original Claim:")
print("The Random Forest model accurately predicts content performance.")

print("\nRevised Claim:")
print("In this dataset, the Random Forest model showed higher accuracy than the rule-based baseline.")
print("The results are observed on the available data and should be used for decision support rather than automatic decision making.")
# Out:
# Original Claim:
# The Random Forest model accurately predicts content performance.
#
# Revised Claim:
# In this dataset, the Random Forest model showed higher accuracy than the rule-based baseline.
# The results are observed on the available data and should be used for decision support rather than automatic decision making.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
